# %%
from dotenv import load_dotenv
load_dotenv()
from src.utils import load_csv_files_into_sqlitedb

# %%
# Out:
# <sqlite3.Connection object at 0x7d1a7a8e65c0>
# <sqlite3.Cursor object at 0x7d1a7aa0b3c0>

# %%
rows = conn.execute("select * from sales limit 5").fetchall()
for row in rows:
    print(dict(row))
# Out:
# {'SalesID': 2719965, 'SalesPersonID': 9, 'CustomerID': 42318, 'ProductID': 1, 'Quantity': 11, 'Discount': 0.0, 'TotalSalesAmount': 931.5896897072188, 'SalesDate': '2018-02-22 23:01:01.500', 'TransactionNumber': 'YN3CUQ37F4SFV93NPZAG', 'CityID': 64, 'CountryID': 32}
# {'SalesID': 1825929, 'SalesPersonID': 15, 'CustomerID': 56369, 'ProductID': 1, 'Quantity': 15, 'Discount': 0.0, 'TotalSalesAmount': 585.7448791709281, 'SalesDate': '2018-02-07 03:39:16.290', 'TransactionNumber': 'VD0U48DL7OCOQWVMD2VE', 'CityID': 26, 'CountryID': 32}
# {'SalesID': 6622058, 'SalesPersonID': 23, 'CustomerID': 38836, 'ProductID': 1, 'Quantity': 10, 'Discount': 0.0, 'TotalSalesAmount': 124.5803702124103, 'SalesDate': '2018-03-21 15:03:36.740', 'TransactionNumber': 'H63VJO5RD8GQY7MEDSAU', 'CityID': 44, 'CountryID': 32}
# {'SalesID': 905005, 'SalesPersonID': 18, 'CustomerID': 65008, 'ProductID': 1, 'Quantity': 17, 'Discount': 0.0, 'TotalSalesAmount': 423.9892988896961, 'SalesDate': '2018-04-30 23:25:17.390', 'TransactionNumber': 'FR9Y8QYDFN632JCN8343', 'CityID': 42, 'CountryID': 32}
# {'SalesID': 5711146, 'SalesPersonID': 21, 'CustomerID': 72492, 'ProductID': 1, 'Quantity': 19, 'Discount': 0.0, 'TotalSalesAmount': 264.4058421980749, 'SalesDate': '2018-01-21 19:57:21.200', 'TransactionNumber': 'MUMJNESSN3M2MXM3X3CQ', 'CityID': 70, 'CountryID': 32}
